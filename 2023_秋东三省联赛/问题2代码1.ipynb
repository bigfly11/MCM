# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
data = pd.read_excel('output4.xlsx')
# Import library for VIF (方差扩大因子)
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
data2=data[['是否吸烟', '开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '是否饮酒', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', '是否饮用黄酒或糯米酒',
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐', '在家吃早餐', '早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '在家吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', '周末在家吃中餐人数',
            '不吃晚餐', '在家吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐', '工作日在家吃晚餐人数', '周末在家吃晚餐人数']]
data100=vif(data2)
data100.to_excel('output.xlsx',index=False)

# %%
data3=data[['是否吸烟', '开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '是否饮酒', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', '是否饮用黄酒或糯米酒',
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐', '在家吃早餐', '早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '在家吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', '周末在家吃中餐人数',
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐', '工作日在家吃晚餐人数', '周末在家吃晚餐人数']]
data99=vif(data3)
data99.to_excel('output.xlsx',index=False)

# %%
data4=data[['是否吸烟', '开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '是否饮酒', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', '是否饮用黄酒或糯米酒',
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐', '在家吃早餐', '早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', '周末在家吃中餐人数',
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐', '工作日在家吃晚餐人数', '周末在家吃晚餐人数']]
data98=vif(data4)
data98.to_excel('output.xlsx',index=False)

# %%
data5=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '是否饮酒', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', '是否饮用黄酒或糯米酒',
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐', '在家吃早餐', '早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', '周末在家吃中餐人数',
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐', '工作日在家吃晚餐人数', '周末在家吃晚餐人数']]
data97=vif(data5)
data97.to_excel('output.xlsx',index=False)

# %%
data6=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', '是否饮用黄酒或糯米酒',
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐', '在家吃早餐', '早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', '周末在家吃中餐人数',
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐', '工作日在家吃晚餐人数', '周末在家吃晚餐人数']]
data96=vif(data6)
data96.to_excel('output.xlsx',index=False)

# %%
data7=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', '是否饮用黄酒或糯米酒',
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐', '在家吃早餐', '早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐', '工作日在家吃晚餐人数', '周末在家吃晚餐人数']]
data95=vif(data7)
data95.to_excel('output.xlsx',index=False)

# %%
data8=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', '是否饮用黄酒或糯米酒',
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐', '在家吃早餐', '早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐', '工作日在家吃晚餐人数']]
data96=vif(data8)
data96.to_excel('output.xlsx',index=False)

# %%
data9=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐', '在家吃早餐', '早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐', '工作日在家吃晚餐人数']]
data94=vif(data9)
data94.to_excel('output.xlsx',index=False)

# %%
data10=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐', '在家吃早餐', '早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data93=vif(data10)
data93.to_excel('output.xlsx',index=False)

# %%
data10=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量', '是否饮用低度白酒', '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data93=vif(data10)
data93.to_excel('output.xlsx',index=False)

# %%
data11=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量',  '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '是否参加体育锻炼', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data92=vif(data11)
data92.to_excel('output.xlsx',index=False)

# %%
data12=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量',  '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '是否饮用葡萄酒', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data91=vif(data12)
data91.to_excel('output.xlsx',index=False)

# %%
data13=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量',  '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐', '工作日在家吃早餐人数', '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data90=vif(data13)
data90.to_excel('output.xlsx',index=False)

# %%
data14=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '是否被动吸烟', '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量',  '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐',  '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data89=vif(data14)
data89.to_excel('output.xlsx',index=False)

# %%
data14=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量',  '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '是否饮用啤酒', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '您做休闲、家务活动的强度', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐',  '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data89=vif(data14)
data89.to_excel('output.xlsx',index=False)

# %%
data14=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量',  '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐',  '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data89=vif(data14)
data89.to_excel('output.xlsx',index=False)

# %%
data14=data[['开始吸烟年龄', '平均每周吸烟天数', '一天吸烟支数', 
            '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量',  '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐',  '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data89=vif(data14)
data89.to_excel('output.xlsx',index=False)

# %%
data14=data[['开始吸烟年龄', '一天吸烟支数', 
            '被动吸烟天数为', '饮酒年数', '是否饮用高度白酒',
            '高度白酒饮用频率', '高度白酒平均每次饮用量',  '低度白酒饮用频率',
            '低度白酒平均每次饮用量', '啤酒饮用频率', '啤酒平均每次饮用量', 
            '黄酒或糯米酒饮用频率', '黄酒或糯米酒平均每次饮用量', '葡萄酒饮用频率', '葡萄酒平均每次饮用量',
            '工作主要属于以下何种活动', '体育锻炼的强度', '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐',  '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位', '单位食堂中餐', '在餐馆或街头吃中餐', '工作日在家吃中餐人数', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data89=vif(data14)
data89.to_excel('output.xlsx',index=False)

# %%
data14=data[['开始吸烟年龄',
            '饮酒年数', 
            
            '啤酒平均每次饮用量', 
          
            '平均每天体育锻炼时间',
            '不吃早餐','早餐带餐到单位', '单位食堂早餐', '在餐馆或街头吃早餐',  '周末在家吃早餐人数',
            '不吃中餐', '中餐带餐到单位',  '在餐馆或街头吃中餐', 
            '不吃晚餐', '晚餐带餐到单位', '单位食堂晚餐', '在餐馆或街头吃晚餐']]
data89=vif(data14)
data89.to_excel('output.xlsx',index=False)
