# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
data=pd.read_excel('output4.xlsx')
data
# Out:
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟  开始吸烟年龄  平均每周吸烟天数  一天吸烟支数  是否被动吸烟  ...  \
# 0     1983   2     4     1   9     3       0         0       0       1  ...
# 1     1994   2     3     1  13     3       0         0       0       1  ...
# 2     1976   1     4     2   4     1      16         7      20       2  ...
# 3     1962   1     4     2  12     3       0         0       0       1  ...
# 4     1968   1     4     2   9     1      20         7      10       1  ...
# ...    ...  ..   ...   ...  ..   ...     ...       ...     ...     ...  ...
# 7830  1974   2     4     2  10     3       0         0       0       2  ...
# 7831  1945   2     2     2  10     3       0         0       0       2  ...
# 7832  1980   1     3     2   9     1      17         7      20       2  ...
# 7833  1965   2     3     2  10     3       0         0       0       1  ...
# 7834  1968   1     3     2   4     2       0         0       0       2  ...
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled_data=sc.fit_transform(data)
data1=pd.DataFrame(scaled_data)
data1.to_excel('outputSC.xlsx',index=False)

# %%
data1
# Out:
#            0         1         2         3         4         5         6    \
# 0     1.093632  0.889301  0.233152 -1.813403  0.377179  0.542274 -0.377680
# 1     1.999005  0.889301 -0.731849 -1.813403  1.438576  0.542274 -0.377680
# 2     0.517486 -1.124478  0.233152  0.059276 -0.949568 -1.979968  0.899456
# 3    -0.634806 -1.124478  0.233152  0.059276  1.173227  0.542274 -0.377680
# 4    -0.140966 -1.124478  0.233152  0.059276  0.377179 -1.979968  1.218740
# ...        ...       ...       ...       ...       ...       ...       ...
# 7830  0.352873  0.889301  0.233152  0.059276  0.642528  0.542274 -0.377680
# 7831 -2.034018  0.889301 -1.696849  0.059276  0.642528  0.542274 -0.377680
# 7832  0.846713 -1.124478 -0.731849  0.059276  0.377179 -1.979968  0.979277
# 7833 -0.387886  0.889301 -0.731849  0.059276  0.642528  0.542274 -0.377680
# 7834 -0.140966 -1.124478 -0.731849  0.059276 -0.949568 -0.718847 -0.377680
#
# ...

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
data=pd.read_excel('预处理最终版本.xlsx')
data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled_data=sc.fit_transform(data)
data1=pd.DataFrame(scaled_data)
data1.to_excel('预处理最终版本SC.xlsx',index=False)

# %%
data
# Out:
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟  开始吸烟年龄  平均每周吸烟天数  一天吸烟支数  是否被动吸烟  ...  \
# 0     1983   2     4     1   9     3       0         0       0       1  ...
# 1     1994   2     3     1  13     3       0         0       0       1  ...
# 2     1976   1     4     2   4     1      16         7      20       2  ...
# 3     1962   1     4     2  12     3       0         0       0       1  ...
# 4     1968   1     4     2   9     1      20         7      10       1  ...
# ...    ...  ..   ...   ...  ..   ...     ...       ...     ...     ...  ...
# 7830  1974   2     4     2  10     3       0         0       0       2  ...
# 7831  1945   2     2     2  10     3       0         0       0       2  ...
# 7832  1980   1     3     2   9     1      17         7      20       2  ...
# 7833  1965   2     3     2  10     3       0         0       0       1  ...
# 7834  1968   1     3     2   4     2       0         0       0       2  ...
#
# ...

# %%
scaled_data.shape
# Out:
# (7835, 174)
