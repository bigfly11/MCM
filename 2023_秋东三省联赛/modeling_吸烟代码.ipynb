# %%
data
# Out:
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟  开始吸烟年龄  平均每周吸烟天数  一天吸烟支数  是否被动吸烟  ...  \
# 0     1983   2     4     1   9   3.0     NaN       NaN     NaN     1.0  ...
# 1     1994   2     3     1  13   3.0     NaN       NaN     NaN     1.0  ...
# 2     1976   1     4     2   4   1.0    16.0       7.0    20.0     2.0  ...
# 3     1962   1     4     2  12   3.0     NaN       NaN     NaN     1.0  ...
# 4     1968   1     4     2   9   1.0    20.0       7.0    10.0     1.0  ...
# ...    ...  ..   ...   ...  ..   ...     ...       ...     ...     ...  ...
# 7830  1974   2     4     2  10   3.0     NaN       NaN     NaN     2.0  ...
# 7831  1945   2     2     2  10   3.0     NaN       NaN     NaN     2.0  ...
# 7832  1980   1     3     2   9   1.0    17.0       7.0    20.0     2.0  ...
# 7833  1965   2     3     2  10   3.0     NaN       NaN     NaN     1.0  ...
# 7834  1968   1     3     2   4   2.0     NaN       NaN     NaN     2.0  ...
#
#         臀围    收缩压   舒张压    脉搏   胆固醇    血糖  高密度脂蛋白  低密度脂蛋白  甘油三酯     尿酸
# 0     92.0   98.0  62.0  70.0  3.79  4.61    1.59    1.88  0.91  210.4
# 1     88.0  104.0  70.0  80.0  4.24  4.59    1.59    2.17  0.81  270.6
# 2     95.0  104.0  70.0  80.0  4.84  4.13    1.33    2.92  1.59  298.2
# 3     92.0   92.0  62.0  72.0  4.80  4.86    1.39    2.97  0.74  412.3
# 4     97.0  106.0  70.0  70.0  5.10  4.41    1.37    3.15  1.87  350.9
# ...    ...    ...   ...   ...   ...   ...     ...     ...   ...    ...
# 7830  90.5   90.0  60.0  72.0  4.48  4.61    1.35    2.77  0.56  214.9
# 7831  99.0  148.0  60.0  81.0  5.74  5.20    1.24    3.91  0.83  209.8
# 7832  92.0   98.0  60.0  72.0  3.92  4.55    0.93    2.46  1.62  227.9
# 7833  92.0  108.0  68.0  64.0  4.40  4.54    1.33    2.69  0.64  230.2
# 7834  89.5   94.0  70.0  78.0  5.43  4.65    1.12    3.71  1.53  349.7
#
# [7835 rows x 231 columns]

# %%
data.describe()
# Out:
#                出生年           性别         文化程度         婚姻状况           职业  \
# count  7835.000000  7835.000000  7835.000000  7835.000000  7835.000000
# mean   1969.712699     1.558392     3.758392     1.968347     7.578558
# std      12.150471     0.496610     1.036335     0.534028     3.768858
# min    1900.000000     1.000000     1.000000     1.000000     1.000000
# 25%    1963.000000     1.000000     3.000000     2.000000     4.000000
# 50%    1972.000000     2.000000     4.000000     2.000000     9.000000
# 75%    1978.000000     2.000000     5.000000     2.000000    10.000000
# max    1994.000000     2.000000     6.000000     5.000000    13.000000
#
#               是否吸烟       开始吸烟年龄     平均每周吸烟天数       一天吸烟支数       是否被动吸烟  ...  \
# count  7833.000000  1420.000000  1469.000000  1503.000000  7751.000000  ...
# mean      2.570024    24.656338     6.600408    15.880240     1.437234  ...
# std       0.793056    18.477236     1.201282     9.600975     0.496077  ...
# min       1.000000     2.000000     1.000000     1.000000     1.000000  ...
# 25%       3.000000    18.000000     7.000000    10.000000     1.000000  ...
# 50%       3.000000    20.000000     7.000000    15.000000     1.000000  ...
# 75%       3.000000    23.000000     7.000000    20.000000     2.000000  ...
# max       3.000000    99.000000     7.000000    66.000000     2.000000  ...
#
#                 臀围          收缩压          舒张压           脉搏          胆固醇  \
# count  7829.000000  7831.000000  7831.000000  7829.000000  7815.000000
# mean     94.069600   114.340697    74.946878    73.365181     4.859578
# std       7.700341    16.111794    10.503055     7.914939     0.993671
# min      10.700000    68.000000    40.000000    46.000000     0.010000
# 25%      89.500000   102.000000    68.000000    68.000000     4.170000
# 50%      94.000000   112.000000    74.000000    72.000000     4.770000
# 75%      98.500000   122.000000    80.000000    78.000000     5.460000
# max     159.000000   218.000000   130.000000   122.000000    11.450000
#
#                 血糖       高密度脂蛋白       低密度脂蛋白         甘油三酯           尿酸
# count  7808.000000  7812.000000  7756.000000  7815.000000  7815.000000
# mean      5.103444     1.229693     3.003011     1.562933   300.511376
# std       1.146315     0.276834     0.757890     1.432604    81.698842
# min       0.000000     0.380000     0.340000     0.050000    88.500000
# 25%       4.630000     1.030000     2.460000     0.830000   241.400000
# 50%       4.900000     1.200000     2.930000     1.180000   290.700000
# 75%       5.240000     1.390000     3.460000     1.800000   351.750000
# max      25.210000     3.280000     8.800000    27.140000   698.100000
#
# [8 rows x 227 columns]

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

data=pd.read_excel('modeling.xlsx')
data.drop(['民族','Unnamed: 4','ID',],axis=1,inplace=True)
data.被动吸烟天数为.fillna("0",inplace=True)
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import numpy as np
## writing a function that takes a dataframe with missing values and outputs it by filling the missing values. 
def completing_values(df,x,y,z,target_column):
    ## gettting all the features except survived
    age_df=df.iloc[:,x:y]
    temp_train = age_df.loc[age_df[target_column].notnull()] 
    temp_test = age_df.loc[age_df[target_column].isnull()] 
#     temp_train = age_df.loc[age_df.是否吸烟.notnull()] ## df with age values
#     temp_test = age_df.loc[age_df.是否吸烟.isnull()] ## df without age values
    
    y = temp_train[target_column].values ## setting target variables(age) in y 
    X = temp_train.iloc[:,x:z ].values
    
    rmse = []
    nestimators = []
    predict_age=[]
    for n in [1000,1050,1100,1150,1200,1250,1300,1350,1400,1450,1500,1550,1600,1650,1700,1750,1800]:
        rfr = RandomForestRegressor(n_estimators=n,n_jobs=-1,random_state=0)
        rfr.fit(X, y)
        y_predict = rfr.predict(temp_train.iloc[:,x:z].values)
        y_test=temp_train[target_column].values
        
        rmse=np.append(rmse,np.sqrt(metrics.mean_squared_error(y_test,y_predict)))
        nestimators=np.append(nestimators,n)
        predicted_age =np.append(predict_age,rfr.predict(temp_test.iloc[:,x:z].values))
    
    index_of_minimum = np.argmin(rmse)#找到rmse数组的最小值，即最优值的索引
    predict_age=predict_age=[index_of_minimum]
    predicted_age1=predicted_age.astype(int)
    print(index_of_minimum)
    print(rmse[index_of_minimum])
    df.loc[df[target_column].isnull(), target_column] = predicted_age1
    


    
    # Creating a bar plot
    sns.set_style('whitegrid')
    plt.plot(nestimators,rmse,'ro',linestyle='dashed',linewidth=1,markersize=10)
    # Add labels to your graph
    plt.xlabel('Feature Importance Score')
    plt.ylabel('Features')
    plt.title("Visualizing Important Features/RMSE")
    
    #plt.savefig('output.png', dpi=4000, bbox_inches='tight')  #将图片保存到磁盘
    plt.show()
    return df

## Implementing the completing_age function in both train and test dataset.

# %%
completing_values(data,0,6,5,'是否吸烟')
# Out:
# 10
# 0.5294707217724954
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟  开始吸烟年龄  平均每周吸烟天数  一天吸烟支数  是否被动吸烟  ...  \
# 0     1983   2     4     1   9   3.0     NaN       NaN     NaN     1.0  ...
# 1     1994   2     3     1  13   3.0     NaN       NaN     NaN     1.0  ...
# 2     1976   1     4     2   4   1.0    16.0       7.0    20.0     2.0  ...
# 3     1962   1     4     2  12   3.0     NaN       NaN     NaN     1.0  ...
# 4     1968   1     4     2   9   1.0    20.0       7.0    10.0     1.0  ...
# ...    ...  ..   ...   ...  ..   ...     ...       ...     ...     ...  ...
# 7830  1974   2     4     2  10   3.0     NaN       NaN     NaN     2.0  ...
# 7831  1945   2     2     2  10   3.0     NaN       NaN     NaN     2.0  ...
# 7832  1980   1     3     2   9   1.0    17.0       7.0    20.0     2.0  ...
# 7833  1965   2     3     2  10   3.0     NaN       NaN     NaN     1.0  ...
# 7834  1968   1     3     2   4   2.0     NaN       NaN     NaN     2.0  ...
#
#         臀围    收缩压   舒张压    脉搏   胆固醇    血糖  高密度脂蛋白  低密度脂蛋白  甘油三酯     尿酸
# 0     92.0   98.0  62.0  70.0  3.79  4.61    1.59    1.88  0.91  210.4
# 1     88.0  104.0  70.0  80.0  4.24  4.59    1.59    2.17  0.81  270.6
# 2     95.0  104.0  70.0  80.0  4.84  4.13    1.33    2.92  1.59  298.2
# 3     92.0   92.0  62.0  72.0  4.80  4.86    1.39    2.97  0.74  412.3
# 4     97.0  106.0  70.0  70.0  5.10  4.41    1.37    3.15  1.87  350.9
# ...    ...    ...   ...   ...   ...   ...     ...     ...   ...    ...
# 7830  90.5   90.0  60.0  72.0  4.48  4.61    1.35    2.77  0.56  214.9
# 7831  99.0  148.0  60.0  81.0  5.74  5.20    1.24    3.91  0.83  209.8
# 7832  92.0   98.0  60.0  72.0  3.92  4.55    0.93    2.46  1.62  227.9
# 7833  92.0  108.0  68.0  64.0  4.40  4.54    1.33    2.69  0.64  230.2
# 7834  89.5   94.0  70.0  78.0  5.43  4.65    1.12    3.71  1.53  349.7
#
# [7835 rows x 231 columns]

# %%
data2=data[data.是否吸烟==2]
data1=data[data.是否吸烟==1]
data3=data[data.是否吸烟==3]
data4=data[data.是否吸烟.isnull()]
data3.开始吸烟年龄.fillna("0", inplace=True)
data3.平均每周吸烟天数.fillna("0", inplace=True)
data3.一天吸烟支数.fillna("0", inplace=True)
data2.开始吸烟年龄.fillna("0", inplace=True)
data2.一天吸烟支数.fillna("0", inplace=True)
data2.平均每周吸烟天数.fillna("0", inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11700\3270817101.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.开始吸烟年龄.fillna("0", inplace=True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11700\3270817101.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.平均每周吸烟天数.fillna("0", inplace=True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11700\3270817101.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3.一天吸烟支数.fillna("0", inplace=True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11700\3270817101.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.开始吸烟年龄.fillna("0", inplace=True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11700\3270817101.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.一天吸烟支数.fillna("0", inplace=True)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11700\3270817101.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.平均每周吸烟天数.fillna("0", inplace=True)

# %%
completing_values(data1,0,7,6,'开始吸烟年龄')
# Out:
# 8
# 13.537604377225026
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟  开始吸烟年龄  平均每周吸烟天数  一天吸烟支数  是否被动吸烟  ...  \
# 2     1976   1     4     2   4   1.0    16.0       7.0    20.0     2.0  ...
# 4     1968   1     4     2   9   1.0    20.0       7.0    10.0     1.0  ...
# 20    1976   1     4     1  12   1.0    20.0       7.0    10.0     2.0  ...
# 24    1962   1     4     2  12   1.0    23.0       7.0    20.0     2.0  ...
# 34    1986   1     4     1   4   1.0    19.0       7.0    15.0     2.0  ...
# ...    ...  ..   ...   ...  ..   ...     ...       ...     ...     ...  ...
# 7782  1959   1     3     2  12   1.0    20.0       7.0    20.0     2.0  ...
# 7786  1972   1     3     2   9   1.0    18.0       7.0    20.0     2.0  ...
# 7801  1970   1     4     2   1   1.0    30.0       7.0    20.0     1.0  ...
# 7825  1982   1     3     2   1   1.0    20.0       7.0     6.0     1.0  ...
# 7832  1980   1     3     2   9   1.0    17.0       7.0    20.0     2.0  ...
#
#          臀围    收缩压   舒张压    脉搏   胆固醇    血糖  高密度脂蛋白  低密度脂蛋白  甘油三酯     尿酸
# 2      95.0  104.0  70.0  80.0  4.84  4.13    1.33    2.92  1.59  298.2
# 4      97.0  106.0  70.0  70.0  5.10  4.41    1.37    3.15  1.87  350.9
# 20     79.0   90.0  60.0  68.0  4.34  4.06    1.20    2.79  0.73  333.1
# 24     99.0  120.0  80.0  80.0  5.43  4.89    1.03    3.87  1.73  310.2
# 34    109.0  112.0  80.0  78.0  4.56  5.50    0.88    3.33  1.05  412.8
# ...     ...    ...   ...   ...   ...   ...     ...     ...   ...    ...
# 7782   93.0  106.0  70.0  82.0  3.88  5.44    0.94    2.56  1.20  226.5
# 7786   97.0  122.0  78.0  78.0  4.39  5.49    0.97    2.87  2.23  309.0
# 7801   94.5  118.0  70.0  76.0  4.89  4.92    1.74    2.56  1.19  302.0
# 7825   85.5  102.0  64.0  65.0  3.60  4.22    1.52    1.72  0.46  271.1
# 7832   92.0   98.0  60.0  72.0  3.92  4.55    0.93    2.46  1.62  227.9
#
# [1503 rows x 231 columns]

# %%
completing_values(data1,0,8,7,'平均每周吸烟天数')
# Out:
# 12
# 0.5611420414090055
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟  开始吸烟年龄  平均每周吸烟天数  一天吸烟支数  是否被动吸烟  ...  \
# 2     1976   1     4     2   4   1.0    16.0       7.0    20.0     2.0  ...
# 4     1968   1     4     2   9   1.0    20.0       7.0    10.0     1.0  ...
# 20    1976   1     4     1  12   1.0    20.0       7.0    10.0     2.0  ...
# 24    1962   1     4     2  12   1.0    23.0       7.0    20.0     2.0  ...
# 34    1986   1     4     1   4   1.0    19.0       7.0    15.0     2.0  ...
# ...    ...  ..   ...   ...  ..   ...     ...       ...     ...     ...  ...
# 7782  1959   1     3     2  12   1.0    20.0       7.0    20.0     2.0  ...
# 7786  1972   1     3     2   9   1.0    18.0       7.0    20.0     2.0  ...
# 7801  1970   1     4     2   1   1.0    30.0       7.0    20.0     1.0  ...
# 7825  1982   1     3     2   1   1.0    20.0       7.0     6.0     1.0  ...
# 7832  1980   1     3     2   9   1.0    17.0       7.0    20.0     2.0  ...
#
#          臀围    收缩压   舒张压    脉搏   胆固醇    血糖  高密度脂蛋白  低密度脂蛋白  甘油三酯     尿酸
# 2      95.0  104.0  70.0  80.0  4.84  4.13    1.33    2.92  1.59  298.2
# 4      97.0  106.0  70.0  70.0  5.10  4.41    1.37    3.15  1.87  350.9
# 20     79.0   90.0  60.0  68.0  4.34  4.06    1.20    2.79  0.73  333.1
# 24     99.0  120.0  80.0  80.0  5.43  4.89    1.03    3.87  1.73  310.2
# 34    109.0  112.0  80.0  78.0  4.56  5.50    0.88    3.33  1.05  412.8
# ...     ...    ...   ...   ...   ...   ...     ...     ...   ...    ...
# 7782   93.0  106.0  70.0  82.0  3.88  5.44    0.94    2.56  1.20  226.5
# 7786   97.0  122.0  78.0  78.0  4.39  5.49    0.97    2.87  2.23  309.0
# 7801   94.5  118.0  70.0  76.0  4.89  4.92    1.74    2.56  1.19  302.0
# 7825   85.5  102.0  64.0  65.0  3.60  4.22    1.52    1.72  0.46  271.1
# 7832   92.0   98.0  60.0  72.0  3.92  4.55    0.93    2.46  1.62  227.9
#
# [1503 rows x 231 columns]

# %%
completing_values(data1,0,9,8,'一天吸烟支数')
# Out:
# 2
# 3.896528170239573
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟  开始吸烟年龄  平均每周吸烟天数  一天吸烟支数  是否被动吸烟  ...  \
# 2     1976   1     4     2   4   1.0    16.0       7.0    20.0     2.0  ...
# 4     1968   1     4     2   9   1.0    20.0       7.0    10.0     1.0  ...
# 20    1976   1     4     1  12   1.0    20.0       7.0    10.0     2.0  ...
# 24    1962   1     4     2  12   1.0    23.0       7.0    20.0     2.0  ...
# 34    1986   1     4     1   4   1.0    19.0       7.0    15.0     2.0  ...
# ...    ...  ..   ...   ...  ..   ...     ...       ...     ...     ...  ...
# 7782  1959   1     3     2  12   1.0    20.0       7.0    20.0     2.0  ...
# 7786  1972   1     3     2   9   1.0    18.0       7.0    20.0     2.0  ...
# 7801  1970   1     4     2   1   1.0    30.0       7.0    20.0     1.0  ...
# 7825  1982   1     3     2   1   1.0    20.0       7.0     6.0     1.0  ...
# 7832  1980   1     3     2   9   1.0    17.0       7.0    20.0     2.0  ...
#
#          臀围    收缩压   舒张压    脉搏   胆固醇    血糖  高密度脂蛋白  低密度脂蛋白  甘油三酯     尿酸
# 2      95.0  104.0  70.0  80.0  4.84  4.13    1.33    2.92  1.59  298.2
# 4      97.0  106.0  70.0  70.0  5.10  4.41    1.37    3.15  1.87  350.9
# 20     79.0   90.0  60.0  68.0  4.34  4.06    1.20    2.79  0.73  333.1
# 24     99.0  120.0  80.0  80.0  5.43  4.89    1.03    3.87  1.73  310.2
# 34    109.0  112.0  80.0  78.0  4.56  5.50    0.88    3.33  1.05  412.8
# ...     ...    ...   ...   ...   ...   ...     ...     ...   ...    ...
# 7782   93.0  106.0  70.0  82.0  3.88  5.44    0.94    2.56  1.20  226.5
# 7786   97.0  122.0  78.0  78.0  4.39  5.49    0.97    2.87  2.23  309.0
# 7801   94.5  118.0  70.0  76.0  4.89  4.92    1.74    2.56  1.19  302.0
# 7825   85.5  102.0  64.0  65.0  3.60  4.22    1.52    1.72  0.46  271.1
# 7832   92.0   98.0  60.0  72.0  3.92  4.55    0.93    2.46  1.62  227.9
#
# [1503 rows x 231 columns]

# %%
completing_values(data2,0,10,9,'是否被动吸烟')
# Out:
# 13
# 0.2656408340653889
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟 开始吸烟年龄 平均每周吸烟天数 一天吸烟支数  是否被动吸烟  ...  \
# 21    1969   1     5     2   4   2.0    2.0        0      0     2.0  ...
# 23    1946   1     3     2  11   2.0   12.0      7.0   24.0     2.0  ...
# 84    1966   1     4     2   1   2.0   16.0      7.0   10.0     2.0  ...
# 92    1969   1     5     2   8   2.0   18.0      7.0   15.0     1.0  ...
# 228   1972   1     5     2   1   2.0   18.0      7.0   15.0     2.0  ...
# ...    ...  ..   ...   ...  ..   ...    ...      ...    ...     ...  ...
# 7740  1979   2     3     2  10   2.0      0        0      0     1.0  ...
# 7755  1959   1     4     2   1   2.0      0        0      0     2.0  ...
# 7756  1973   1     3     2   9   2.0      0        0      0     2.0  ...
# 7781  1967   2     3     1   3   2.0      0        0      0     2.0  ...
# 7834  1968   1     3     2   4   2.0      0        0      0     2.0  ...
#
#          臀围    收缩压   舒张压    脉搏   胆固醇    血糖  高密度脂蛋白  低密度脂蛋白  甘油三酯     尿酸
# 21    100.0  122.0  80.0  72.0  4.31  5.19    0.84    2.76  2.59  339.9
# 23     93.0  170.0  96.0  68.0  4.27  4.84    1.34    2.65  0.52  204.9
# 84     99.0  104.0  80.0  80.0  7.51  4.39    2.16    4.48  1.81  374.0
# 92     85.4   84.0  60.0  64.0  4.62  4.87    1.23    2.87  1.06  218.9
# 228   108.5  120.0  80.0  80.0  5.34  4.74    1.51    3.22  1.87  421.1
# ...     ...    ...   ...   ...   ...   ...     ...     ...   ...    ...
# 7740   83.4   98.0  70.0  80.0  4.24  9.72    1.66    2.36  0.34  139.5
# 7755   97.5  130.0  94.0  76.0  5.66  5.22    0.98    3.70  4.04  460.4
# 7756   97.3  130.0  92.0  70.0  4.71  5.39    1.11    2.89  2.68  282.9
# 7781   90.5  112.0  66.0  76.0  4.96  5.17    1.21    3.18  2.03  333.5
# 7834   89.5   94.0  70.0  78.0  5.43  4.65    1.12    3.71  1.53  349.7
#
# [363 rows x 231 columns]

# %%
completing_values(data3,0,10,9,'是否被动吸烟')
# Out:
# 15
# 0.3910375727557262
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟 开始吸烟年龄 平均每周吸烟天数 一天吸烟支数  是否被动吸烟  ...  \
# 0     1983   2     4     1   9   3.0      0        0      0     1.0  ...
# 1     1994   2     3     1  13   3.0      0        0      0     1.0  ...
# 3     1962   1     4     2  12   3.0      0        0      0     1.0  ...
# 5     1980   2     3     2  10   3.0      0        0      0     1.0  ...
# 6     1980   2     5     2   8   3.0      0        0      0     1.0  ...
# ...    ...  ..   ...   ...  ..   ...    ...      ...    ...     ...  ...
# 7828  1972   2     2     2   9   3.0      0        0      0     2.0  ...
# 7829  1944   2     2     2  10   3.0      0        0      0     1.0  ...
# 7830  1974   2     4     2  10   3.0      0        0      0     2.0  ...
# 7831  1945   2     2     2  10   3.0      0        0      0     2.0  ...
# 7833  1965   2     3     2  10   3.0      0        0      0     1.0  ...
#
#          臀围    收缩压   舒张压    脉搏   胆固醇    血糖  高密度脂蛋白  低密度脂蛋白  甘油三酯     尿酸
# 0      92.0   98.0  62.0  70.0  3.79  4.61    1.59    1.88  0.91  210.4
# 1      88.0  104.0  70.0  80.0  4.24  4.59    1.59    2.17  0.81  270.6
# 3      92.0   92.0  62.0  72.0  4.80  4.86    1.39    2.97  0.74  412.3
# 5      96.0   90.0  60.0  80.0  5.82  4.68    1.67    3.62  0.91  242.2
# 6      92.0  108.0  64.0  74.0  5.42  5.13    1.16    3.70  0.84  276.7
# ...     ...    ...   ...   ...   ...   ...     ...     ...   ...    ...
# 7828   99.5  118.0  72.0  80.0  3.87  4.89    0.99    2.36  2.25  287.2
# 7829  104.0  136.0  64.0  82.0  4.89  7.19    1.02    3.06  3.83  231.7
# 7830   90.5   90.0  60.0  72.0  4.48  4.61    1.35    2.77  0.56  214.9
# 7831   99.0  148.0  60.0  81.0  5.74  5.20    1.24    3.91  0.83  209.8
# 7833   92.0  108.0  68.0  64.0  4.40  4.54    1.33    2.69  0.64  230.2
#
# [5969 rows x 231 columns]

# %%
completing_values(data1,0,10,9,'是否被动吸烟')
# Out:
# 16
# 0.16765516469131383
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟  开始吸烟年龄  平均每周吸烟天数  一天吸烟支数  是否被动吸烟  ...  \
# 2     1976   1     4     2   4   1.0    16.0       7.0    20.0     2.0  ...
# 4     1968   1     4     2   9   1.0    20.0       7.0    10.0     1.0  ...
# 20    1976   1     4     1  12   1.0    20.0       7.0    10.0     2.0  ...
# 24    1962   1     4     2  12   1.0    23.0       7.0    20.0     2.0  ...
# 34    1986   1     4     1   4   1.0    19.0       7.0    15.0     2.0  ...
# ...    ...  ..   ...   ...  ..   ...     ...       ...     ...     ...  ...
# 7782  1959   1     3     2  12   1.0    20.0       7.0    20.0     2.0  ...
# 7786  1972   1     3     2   9   1.0    18.0       7.0    20.0     2.0  ...
# 7801  1970   1     4     2   1   1.0    30.0       7.0    20.0     1.0  ...
# 7825  1982   1     3     2   1   1.0    20.0       7.0     6.0     1.0  ...
# 7832  1980   1     3     2   9   1.0    17.0       7.0    20.0     2.0  ...
#
#          臀围    收缩压   舒张压    脉搏   胆固醇    血糖  高密度脂蛋白  低密度脂蛋白  甘油三酯     尿酸
# 2      95.0  104.0  70.0  80.0  4.84  4.13    1.33    2.92  1.59  298.2
# 4      97.0  106.0  70.0  70.0  5.10  4.41    1.37    3.15  1.87  350.9
# 20     79.0   90.0  60.0  68.0  4.34  4.06    1.20    2.79  0.73  333.1
# 24     99.0  120.0  80.0  80.0  5.43  4.89    1.03    3.87  1.73  310.2
# 34    109.0  112.0  80.0  78.0  4.56  5.50    0.88    3.33  1.05  412.8
# ...     ...    ...   ...   ...   ...   ...     ...     ...   ...    ...
# 7782   93.0  106.0  70.0  82.0  3.88  5.44    0.94    2.56  1.20  226.5
# 7786   97.0  122.0  78.0  78.0  4.39  5.49    0.97    2.87  2.23  309.0
# 7801   94.5  118.0  70.0  76.0  4.89  4.92    1.74    2.56  1.19  302.0
# 7825   85.5  102.0  64.0  65.0  3.60  4.22    1.52    1.72  0.46  271.1
# 7832   92.0   98.0  60.0  72.0  3.92  4.55    0.93    2.46  1.62  227.9
#
# [1503 rows x 231 columns]

# %%
data=pd.concat([data1,data2,data3,data4],axis=0,ignore_index=True)
data
# Out:
#        出生年  性别  文化程度  婚姻状况  职业  是否吸烟 开始吸烟年龄 平均每周吸烟天数 一天吸烟支数  是否被动吸烟  ...  \
# 0     1976   1     4     2   4   1.0   16.0      7.0   20.0     2.0  ...
# 1     1968   1     4     2   9   1.0   20.0      7.0   10.0     1.0  ...
# 2     1976   1     4     1  12   1.0   20.0      7.0   10.0     2.0  ...
# 3     1962   1     4     2  12   1.0   23.0      7.0   20.0     2.0  ...
# 4     1986   1     4     1   4   1.0   19.0      7.0   15.0     2.0  ...
# ...    ...  ..   ...   ...  ..   ...    ...      ...    ...     ...  ...
# 7830  1972   2     2     2   9   3.0      0        0      0     2.0  ...
# 7831  1944   2     2     2  10   3.0      0        0      0     1.0  ...
# 7832  1974   2     4     2  10   3.0      0        0      0     2.0  ...
# 7833  1945   2     2     2  10   3.0      0        0      0     2.0  ...
# 7834  1965   2     3     2  10   3.0      0        0      0     1.0  ...
#
#          臀围    收缩压   舒张压    脉搏   胆固醇    血糖  高密度脂蛋白  低密度脂蛋白  甘油三酯     尿酸
# 0      95.0  104.0  70.0  80.0  4.84  4.13    1.33    2.92  1.59  298.2
# 1      97.0  106.0  70.0  70.0  5.10  4.41    1.37    3.15  1.87  350.9
# 2      79.0   90.0  60.0  68.0  4.34  4.06    1.20    2.79  0.73  333.1
# 3      99.0  120.0  80.0  80.0  5.43  4.89    1.03    3.87  1.73  310.2
# 4     109.0  112.0  80.0  78.0  4.56  5.50    0.88    3.33  1.05  412.8
# ...     ...    ...   ...   ...   ...   ...     ...     ...   ...    ...
# 7830   99.5  118.0  72.0  80.0  3.87  4.89    0.99    2.36  2.25  287.2
# 7831  104.0  136.0  64.0  82.0  4.89  7.19    1.02    3.06  3.83  231.7
# 7832   90.5   90.0  60.0  72.0  4.48  4.61    1.35    2.77  0.56  214.9
# 7833   99.0  148.0  60.0  81.0  5.74  5.20    1.24    3.91  0.83  209.8
# 7834   92.0  108.0  68.0  64.0  4.40  4.54    1.33    2.69  0.64  230.2
#
# [7835 rows x 231 columns]

# %%
data.to_excel('output7.xlsx',index=False)
